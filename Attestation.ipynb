# %% [markdown]
# <a href="https://colab.research.google.com/github/Eltralo/HW_du/blob/main/Attestation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from collections import Counter
from collections import defaultdict
from collections import OrderedDict
from collections import deque
import pandas as pd
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
products = {'juice':114.99,'sausage':50}
stocks = {'bread': '25%','juice': '15%','sausage':'50%' }

def apply_discounts(products,stocks):
  new_prices = {}
  for key in products.keys():
    if key in stocks.keys():
      discount = float(stocks[key].strip('%')) / 100
      new_prices[key]=round(products[key]*(1-discount),2)
  return new_prices

print(apply_discounts(products,stocks))
# Out:
# {'juice': 97.74, 'sausage': 25.0}

# %%
bt_data = pd.read_csv("C:\Data_sets\dst-3.0_16_1_hh_database.csv",sep = ';')
st_data = pd.read_csv('',sep = ';')
merged = bt_data.merge(
    st_data,
    left_on = ['Country', 'Total'],
    right_on = ['Country', 'Total',],
    how = 'left'
)

# %%
merged['Date'] = pd.to_datetime(merged['Date'], dayfirst=True)
merged['Month'] =merged['Date'].dt.to_period('M')
merged['Year']=merged['Date'].dt.to_period.year
merged['Month']= merged['Date'].dt.to_period.month
merged['Day']= merged['Date'].dt.to_period.day
merged_df = merged.groupby(['Year', 'Month']).sum()
merged['Выработка в день'] = merged['Выработка'].apply(lambda x:x)
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()

# %%
line_data = merged.groupby('Month', as_index=False).sum()
fig = px.line(
    data_frame=line_data, #датафрейм
    x='Month', #ось абсцисс
    y=['Выработка'], #ось ординат
    height=500, #высота
    width=1000, #ширина
    title='' #заголовок
)
fig.show()

# %%
import pandas as pd

# Создание примера таблицы с данными
data = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}
df = pd.DataFrame(data)
df.head()

# Обращение к предшествующему элементу из столбца
prev_element = df['A'].shift()

print(prev_element)
df.head()
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# Name: A, dtype: float64
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
